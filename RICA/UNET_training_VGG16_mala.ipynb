# %% [markdown]
# [consejos google pro](https://colab.research.google.com/notebooks/pro.ipynb)

# %% [markdown]
# # SEGMENTACION MEDIANTE U-NET + VGG16 y
#
#
#     def dice_loss(y_true, y_pred, smooth=1) #smooth=1e-5
#       y_true = tf.cast(y_true, tf.float32)
#       intersection = tf.reduce_sum(y_true * y_pred)
#       suma = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
#       dice_score = (2.0 * intersection + smooth) / (suma + smooth)
#       dice_loss = 1.0 - dice_score
#       return dice_loss

# %% [markdown]
# ## 1.4 Codigo

# %%
# EL DATA AUGMENTATION QUE VA ES EL DE ESTA NOTEBOOK


## Imports
import os
import random

import numpy as np
import cv2
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras


## Seeding
seed = 2019
random.seed = seed
np.random.seed = seed
tf.seed = seed

# %%
from PIL import Image

def image_display(image_pathlist, mask_pathlist, index):
    # input: image and mask filepath and the index
    # output matplotlib images
    image = Image.open(image_pathlist[index]).convert("L") #agregamos .convert("L")
    imagearray = np.array(image)
    print('Image shape: ', imagearray.shape)


    mask = Image.open(mask_pathlist[index]).convert("L") #agregamos .convert("L")
    maskarray = np.array(mask)
    print('Mask shape: ', maskarray.shape)

    #fig, ax = plt.subplots(3,figsize=(5,10))
    fig, ax = plt.subplots(1,3,figsize=(14,4)) #cambié para que se vean horizontales
    ax[0].imshow(imagearray, aspect='auto', cmap='gray')
    ax[1].imshow(maskarray, aspect='auto', cmap='gray')
    ax[2].imshow(imagearray, aspect='auto', cmap = 'gray')
    ax[2].imshow(maskarray, cmap = 'Reds', aspect='auto', alpha = 0.4)

# %%
def finetune_unfreezeall(base_model):
    base_model = base_model

    # unfreeze the contracting path and freeze the expanding path
    for layer in base_model.layers:
        if layer.name in ['block1_conv1', 'block1_conv2', 'block1_pool',
                          'block2_conv1', 'block2_conv2', 'block2_pool',
                          'block3_conv1', 'block3_conv2', 'block3_conv3', 'block3_pool',
                          'block4_conv1', 'block4_conv2', 'block4_conv3', 'block4_pool',
                          'block5_conv1', 'block5_conv2', 'block5_conv3']:
            layer.trainable = True

    return base_model

# %% [markdown]
# ## Clase para Aumentacion de datos completa, con esquinas y doble flip

# %%
class DataAugmentation:
    def __init__(self, images):
        self.images = images
        self.output = []

    def process_images(self):
        image_files = self.images
        for file_name in image_files:
            image = file_name
            if image.shape[0] < 512:
                diff_rows = 512 - image.shape[0]
                image = np.vstack((image, np.zeros((diff_rows, image.shape[1]), dtype=np.uint8)))

            if image.shape[1] < 512:
                diff_cols = 512 - image.shape[1]
                image = np.hstack((image, np.zeros((image.shape[0], diff_cols), dtype=np.uint8)))

            self.apply_transformations(image)


    def apply_transformations(self, image):



        for i in range(-4,5,8):#range(-4,5,4):   #range(-4,5,2)=[-4,-2, 0, 2, 4]
          for j in range(-4,5,8):  #range(-4,5,4)=[-4, 0, 4]
            translate = self.apply_translation(image, 32 * i, 32 * j)
            translated_cropped = self.adjust_image_size(translate, 512, 512)
            self.save_transformed_images(translated_cropped)

            flip_horizontal_right = cv2.flip(translated_cropped, 1)
            self.save_transformed_images(flip_horizontal_right)

            flip_vertical_right = cv2.flip(translated_cropped, 0)
            self.save_transformed_images(flip_vertical_right)

            flip_both_right = cv2.flip(flip_horizontal_right, 0)  #agregado!
            self.save_transformed_images(flip_both_right)     #agregado!



    def apply_translation(self, image, x_offset, y_offset):
        rows, cols = image.shape
        M = np.float32([[1, 0, x_offset], [0, 1, y_offset]])
        translated_image = cv2.warpAffine(image, M, (cols, rows))
        return translated_image

    def save_transformed_images(self, image):

        self.output.append(image)

    def save_image(self, image):
        self.output.append(image)


    def adjust_image_size(self, image, target_width, target_height):
        height, width = image.shape
        x_offset = (width - target_width) // 2
        y_offset = (height - target_height) // 2
        new_image = image[y_offset:y_offset + target_height, x_offset:x_offset + target_width]

        return new_image

# %%
def image_comparac(monocroma, etiqueta, red):
    # input: image and mask filepath and the index
    # output matplotlib images

    fig, ax = plt.subplots(1,4,figsize=(16,4)) #cambié para que se vean horizontales
    ax[0].imshow(monocroma, aspect='auto', cmap='gray')
    ax[0].set_title('monocroma')
    ax[1].imshow(etiqueta, aspect='auto', cmap='gray')
    ax[1].set_title('Ground Truth')
    ax[2].set_title('Predicción')
    ax[2].imshow(red, aspect='auto', cmap = 'gray')
    ax[3].imshow(monocroma, aspect='auto', cmap='gray')
    ax[3].imshow(etiqueta, cmap = 'Reds', aspect='auto', alpha = 0.4)
    ax[3].imshow(red, cmap = 'Blues', aspect='auto', alpha = 0.4)

# %% [markdown]
# ## Leer las imagenes

# %%
# Este comando es para leer los archivos directamente desde Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path_train = "/content/drive/MyDrive/Proyecto_Sadosky/base_final/clean_database/train"
path_test = "/content/drive/MyDrive/Proyecto_Sadosky/base_final/clean_database/test"

# %%
path_train = "/content/drive/MyDrive/Sadosky_EcoDoppler/Investigación/Procesamiento/base_final/clean_database/train"
path_test = "/content/drive/MyDrive/Sadosky_EcoDoppler/Investigación/Procesamiento/base_final/clean_database/test"

# %%
#database_path = os.path.join(path_train, "clean_png_train")
database_path = path_train

files_train = os.listdir(database_path)

images_train = [item for item in files_train if 'labeled' not in item]


random.shuffle(images_train)

print(f'Total number of Train images: {len(images_train)}')
print(images_train)


train_ids = images_train
# Out:
# Total number of Train images: 493
# ['171.png', '100.png', '442.png', '116.png', '149.png', '373.png', '374.png', '249.png', '92.png', '134.png', '325.png', '280.png', '270.png', '322.png', '206.png', '331.png', '277.png', '125.png', '464.png', '371.png', '233.png', '144.png', '118.png', '275.png', '241.png', '83.png', '98.png', '84.png', '237.png', '346.png', '147.png', '337.png', '63.png', '438.png', '422.png', '123.png', '426.png', '481.png', '190.png', '385.png', '105.png', '412.png', '386.png', '347.png', '28.png', '393.png', '345.png', '194.png', '117.png', '431.png', '17.png', '414.png', '436.png', '159.png', '6.png', '289.png', '305.png', '353.png', '70.png', '449.png', '97.png', '169.png', '329.png', '309.png', '400.png', '111.png', '389.png', '350.png', '182.png', '88.png', '380.png', '312.png', '396.png', '441.png', '360.png', '450.png', '94.png', '356.png', '160.png', '486.png', '42.png', '465.png', '218.png', '495.png', '225.png', '330.png', '2.png', '204.png', '40.png', '163.png', '552.png', '397.png', '137.png', '267.png', '256.png', '496.png', '35.png', '38.png', '62.png', '404.png', '262.png', '429.png', '219.png', '27.png', '201.png', '314.png', '476.png', '188.png', '416.png', '477.png', '41.png', '32.png', '420.png', '550.png', '424.png', '119.png', '203.png', '318.png', '221.png', '484.png', '413.png', '213.png', '10.png', '293.png', '306.png', '12.png', '133.png', '334.png', '33.png', '287.png', '458.png', '96.png', '297.png', '372.png', '313.png', '161.png', '93.png', '165.png', '7.png', '104.png', '242.png', '47.png', '5.png', '19.png', '65.png', '101.png', '358.png', '335.png', '466.png', '223.png', '368.png', '178.png', '304.png', '291.png', '430.png', '13.png', '8.png', '197.png', '398.png', '175.png', '80.png', '281.png', '286.png', '49.png', '359.png', '383.png', '264.png', '379.png', '376.png', '54.png', '14.png', '227.png', '328.png', '252.png', '131.png', '136.png', '303.png', '228.png', '220.png', '230.png', '315.png', '152.png', '198.png', '419.png', '375.png', '148.png', '459.png', '11.png', '253.png', '43.png', '381.png', '384.png', '120.png', '143.png', '551.png', '210.png', '425.png', '365.png', '184.png', '180.png', '145.png', '340.png', '447.png', '130.png', '266.png', '44.png', '446.png', '276.png', '473.png', '121.png', '323.png', '402.png', '439.png', '107.png', '212.png', '288.png', '349.png', '437.png', '75.png', '202.png', '341.png', '72.png', '155.png', '489.png', '300.png', '319.png', '548.png', '448.png', '443.png', '69.png', '478.png', '139.png', '15.png', '457.png', '333.png', '24.png', '29.png', '170.png', '211.png', '463.png', '452.png', '127.png', '342.png', '434.png', '454.png', '151.png', '290.png', '9.png', '18.png', '382.png', '339.png', '488.png', '87.png', '224.png', '245.png', '269.png', '321.png', '39.png', '292.png', '244.png', '246.png', '132.png', '82.png', '299.png', '59.png', '310.png', '445.png', '363.png', '45.png', '370.png', '455.png', '112.png', '51.png', '268.png', '183.png', '462.png', '391.png', '4.png', '546.png', '31.png', '273.png', '250.png', '20.png', '86.png', '103.png', '547.png', '235.png', '95.png', '193.png', '231.png', '357.png', '352.png', '251.png', '236.png', '162.png', '16.png', '26.png', '433.png', '64.png', '428.png', '274.png', '25.png', '196.png', '444.png', '216.png', '479.png', '366.png', '99.png', '316.png', '296.png', '53.png', '271.png', '168.png', '226.png', '122.png', '278.png', '362.png', '214.png', '294.png', '67.png', '361.png', '179.png', '158.png', '369.png', '157.png', '255.png', '307.png', '57.png', '142.png', '189.png', '377.png', '338.png', '60.png', '81.png', '66.png', '172.png', '395.png', '79.png', '174.png', '48.png', '23.png', '407.png', '440.png', '298.png', '156.png', '166.png', '301.png', '411.png', '460.png', '348.png', '456.png', '129.png', '115.png', '327.png', '150.png', '261.png', '295.png', '195.png', '475.png', '487.png', '409.png', '110.png', '238.png', '1.png', '113.png', '128.png', '109.png', '364.png', '186.png', '177.png', '181.png',  ...

# %%
train_images = []
train_masks = []

for image_id in train_ids:


    image_path = os.path.join(database_path, str(image_id))
    train_images.append(image_path)
    mask_path = os.path.join(database_path, image_id.replace(".png","")) + "_labeled.png"
    train_masks.append(mask_path)

# %% [markdown]
# ## Cargo las imagenes en memoria

# %%
Xtrain = []

Ytrain = []


for image_id in train_ids:


    image_path = os.path.join(database_path, str(image_id))
    mask_path = os.path.join(database_path, image_id.replace(".png","")) + "_labeled.png"
    image = cv2.imread(image_path, 0)
    mask = cv2.imread(mask_path, 0)
    Xtrain.append(image)
    Ytrain.append(mask)

# %%
# hacemos la aumentacion de datos de train

X_train_data_augmentation = DataAugmentation(Xtrain)
X_train_data_augmentation.process_images()

# %%
Xtrain =  X_train_data_augmentation.output

# %%
X_train = np.asarray(Xtrain, dtype=np.uint8)
print('Xtrain:',X_train.shape)
# Out:
# Xtrain: (7888, 512, 512)

# %%
Y_train_data_augmentation = DataAugmentation(Ytrain)
Y_train_data_augmentation.process_images()

# %%
Ytrain = Y_train_data_augmentation.output

# %%
print(Y_train_data_augmentation.output[1].shape)
# Out:
# (512, 512)

# %%
Y_train = np.asarray(Ytrain, dtype=bool)
print('Ytrain:',Y_train.shape)
# Out:
# Ytrain: (7888, 512, 512)

# %%
len(X_train)
# Out:
# 7888

# %% [markdown]
# ## Metricas para medir el desempeno de la red

# %%
import tensorflow.keras.backend as K

# intersection over union

def jacard_coef(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    intersection = K.sum(y_true * y_pred)

    return (intersection + 1.0) / (K.sum(y_true) + K.sum(y_pred) - intersection + 1.0)

def jacard_coef_loss(y_true, y_pred):
    return -jacard_coef(y_true, y_pred)

# %%
def jacard_coef_np(y_true, y_pred):
  y_true=y_true.astype('float32')
  y_pred=y_pred.astype('float32')
  intersection = np.sum(y_true * y_pred)
  return (intersection + 1.0) / (np.sum(y_true) + np.sum(y_pred) - intersection + 1.0)

# %%
def dice_coef_np(y_true, y_pred):
  y_true=y_true.astype('float32')
  y_pred=y_pred.astype('float32')
  intersection = np.sum(y_true * y_pred)
  return (2*intersection + 1.0) / (np.sum(y_true) + np.sum(y_pred) + 1.0)

# %%
import tensorflow.keras.backend as K

def dice_coefficient(y_true, y_pred, smooth=1):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    intersection = K.sum(y_true * y_pred)
    suma = K.sum(y_true) + K.sum(y_pred)
    dice = (2.0 * intersection + smooth) / (suma + smooth)
    return dice

def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

# %%
import tensorflow as tf
# este no funciona

def dice_loss_modif0(y_true, y_pred, smooth=1e-5):
    y_true = tf.cast(y_true, tf.float32)

    if sum(y_true) == 0:               #se agrega para controlar los falsos positivos cuando no hay placa en el Ground Truth
      # no tengo placa
      dice_loss = tf.reduce_sum(y_pred) * smooth #en nuestro caso también puede ser /(512**2)

    else:
      intersection = tf.reduce_sum(y_true * y_pred)
      suma = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
      dice_score = (2.0 * intersection + smooth) / (suma + smooth)
      dice_loss = 1.0 - dice_score

    return dice_loss

# %%
import tensorflow as tf
# este no funciona bien para smooth=1e-5

def dice_loss_modif(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    dice_score = (2.0 * intersection + smooth) / (union + smooth)
    dice_loss = - dice_score+(tf.reduce_sum(y_pred)*smooth)**2
    return dice_loss

# %%
import tensorflow as tf

def dice_loss(y_true, y_pred, smooth=1): #smooth=1e-5
    y_true = tf.cast(y_true, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    suma = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    dice_score = (2.0 * intersection + smooth) / (suma + smooth)
    dice_loss = 1.0 - dice_score
    return dice_loss

# %%
def weighted_binary_crossentropy(y_true, y_pred):

    one_weight = 0.89
    zero_weight = 0.11
    # Original binary crossentropy (see losses.py):
    # K.mean(K.binary_crossentropy(y_true, y_pred), axis=-1)

    # Calculate the binary crossentropy
    y_true = tf.cast(y_true, tf.float32)
    b_ce = K.binary_crossentropy(y_true, y_pred)

    # Apply the weights
    weight_vector = y_true * one_weight + (1. - y_true) * zero_weight
    weighted_b_ce = weight_vector * b_ce

    # Return the mean error
    return K.mean(weighted_b_ce)

# %% [markdown]
# ## Modelo de Red neuronal

# %%
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from keras.layers import concatenate, Conv2DTranspose, Conv2D, Dropout
from keras.layers import Input
from keras.models import Model


# https://github.com/dorltcheng/Transfer-Learning-U-Net-Deep-Learning-for-Lung-Ultrasound-Segmentation/blob/main/V_Unet/V_Unet_v1_1.ipynb

from tensorflow.keras.regularizers import l2

def TL_unet_model(input_shape):
  #def TL_unet_model(input_shape, dropout_rate=0.5, l2_penalty=1e-3):
    # input: input_shape (height, width, channels)
    # return model

    img_input = Input(shape=(input_shape, input_shape, 1))
    img_conc = concatenate(([img_input, img_input, img_input]))


    base_VGG = VGG16(include_top = False,
                   weights = "imagenet",
                   input_tensor=img_conc)

    # freezing all layers in VGG16
    for layer in base_VGG.layers:
        layer.trainable = False

    # the bridge (exclude the last maxpooling layer in VGG16)
    # bridge = base_VGG.get_layer("block5_conv3").output

    bridge = base_VGG.output

    print(bridge.shape)

    # Decoder now
    up1 = Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(bridge)
    print(up1.shape)
    concat_1 = concatenate([up1, base_VGG.get_layer("block5_conv3").output], axis=3)
    conv6 = Conv2D(512, (3, 3), activation='relu', padding='same')(concat_1)
    conv6 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv6)
    #conv6 = Dropout(dropout_rate)(conv6)

    up2 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv6)
    print(up2.shape)
    concat_2 = concatenate([up2, base_VGG.get_layer("block4_conv3").output], axis=3)
    conv7 = Conv2D(256, (3, 3), activation='relu', padding='same')(concat_2)
    conv7 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv7)
    #conv7 = Dropout(dropout_rate)(conv7)

    up3 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv7)
    print(up3.shape)
    concat_3 = concatenate([up3, base_VGG.get_layer("block3_conv3").output], axis=3)
    conv8 = Conv2D(128, (3, 3), activation='relu', padding='same')(concat_3)
    conv8 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv8)
    #conv8 = Dropout(dropout_rate)(conv8)

    up4 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv8)
    print(up4.shape)
    concat_4 = concatenate([up4, base_VGG.get_layer("block2_conv2").output], axis=3)
    conv9 = Conv2D(64, (3, 3), activation='relu', padding='same')(concat_4)
    conv9 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv9)
    #conv9 = Dropout(dropout_rate)(conv9)

    # probando
    up5 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv9)
    print(up5.shape)
    concat_5 = concatenate([up5, base_VGG.get_layer("block1_conv2").output], axis=3)
    conv10 = Conv2D(32, (3, 3), activation='relu', padding='same')(concat_5)
    conv10 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv10)
    #conv10 = Dropout(dropout_rate)(conv10)

    conv11 = Conv2D(1, (1, 1), activation='sigmoid')(conv10)
    print(conv11.shape)

    model = Model(inputs=[base_VGG.input], outputs=[conv11])

    return model

# %%
from tensorflow.keras.optimizers import Adam

# NOTA: cuando uso "adam", sin especificar el Learning rate, el algoritmo no converge y hace todo mal

# model = model_build_func((512, 512, 1),1,True)
model = TL_unet_model(512)
model.compile(optimizer=Adam(learning_rate=1e-4), loss=[dice_loss], metrics=[jacard_coef])
# model.compile(optimizer="sgd", loss=[dice_loss], metrics=[jacard_coef])
model.summary()
# Out:
# (None, 16, 16, 512)
# (None, 32, 32, 512)
# (None, 64, 64, 256)
# (None, 128, 128, 128)
# (None, 256, 256, 64)
# (None, 512, 512, 32)
# (None, 512, 512, 1)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 512, 512, 1)]        0         []
#
#  concatenate (Concatenate)   (None, 512, 512, 3)          0         ['input_1[0][0]',
#                                                                      'input_1[0][0]',
#                                                                      'input_1[0][0]']
#
#  block1_conv1 (Conv2D)       (None, 512, 512, 64)         1792      ['concatenate[0][0]']
#
#  block1_conv2 (Conv2D)       (None, 512, 512, 64)         36928     ['block1_conv1[0][0]']
#
#  block1_pool (MaxPooling2D)  (None, 256, 256, 64)         0         ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)       (None, 256, 256, 128)        73856     ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)       (None, 256, 256, 128)        147584    ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 128, 128, 128)        0         ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)       (None, 128, 128, 256)        295168    ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)       (None, 128, 128, 256)        590080    ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)       (None, 128, 128, 256)        590080    ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 64, 64, 256)          0         ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)       (None, 64, 64, 512)          1180160   ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)       (None, 64, 64, 512)          2359808   ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)       (None, 64, 64, 512)          2359808   ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 32, 32, 512)          0         ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)       (None, 32, 32, 512)          2359808   ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)       (None, 32, 32, 512)          2359808   ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)       (None, 32, 32, 512)          2359808   ['block5_conv2[0][0]']
#
#  block5_pool (MaxPooling2D)  (None, 16, 16, 512)          0         ['block5_conv3[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 512)          1049088   ['block5_pool[0][0]']
#  anspose)
#
#  concatenate_1 (Concatenate  (None, 32, 32, 1024)         0         ['conv2d_transpose[0][0]',
#  )                                                                   'block5_conv3[0][0]']
#
#  conv2d (Conv2D)             (None, 32, 32, 512)          4719104   ['concatenate_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 512)          2359808   ['conv2d[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 256)          524544    ['conv2d_1[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 64, 64, 768)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'block4_conv3[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 256)          1769728   ['concatenate_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 256)          590080    ['conv2d_2[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 128)        131200    ['conv2d_3[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 128, 128, 384)        0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'block3_conv3[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 128)        442496    ['concatenate_3[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 128, 128, 128)        147584    ['conv2d_4[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 64)         32832     ['conv2d_5[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 256, 256, 192)        0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'block2_conv2[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 256, 256, 64)         110656    ['concatenate_4[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 256, 256, 64)         36928     ['conv2d_6[0][0]']
#
#  conv2d_transpose_4 (Conv2D  (None, 512, 512, 32)         8224      ['conv2d_7[0][0]']
#  Transpose)
#
#  concatenate_5 (Concatenate  (None, 512, 512, 96)         0         ['conv2d_transpose_4[0][0]',
#  )                                                                   'block1_conv2[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 512, 512, 32)         27680     ['concatenate_5[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 512, 512, 32)         9248      ['conv2d_8[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 512, 512, 1)          33        ['conv2d_9[0][0]']
#
# ==================================================================================================
# Total params: 26673921 (101.75 MB)
# Trainable params: 11959233 (45.62 MB)
# Non-trainable params: 14714688 (56.13 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Entrenamiento

# %% [markdown]
# ## path resultados del modelo

# %%
path='/content/drive/MyDrive/Proyecto_Sadosky/modelo_final/resultados/VGG16/'
path ="/content/drive/MyDrive/Sadosky_EcoDoppler/Investigación/Procesamiento/modelo_final/resultados/VGG16/"

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
## Validation Data Size  80:20

epochs = 40
batch_size = 16 # con 32 me da error

checkpoint_path = path+'unet_plaque_segmentation.hdf5'

model_checkpoint = ModelCheckpoint(checkpoint_path,
                                    verbose=1,
                                    monitor='val_loss',
                                    save_best_only=True)

callbacks_list = [model_checkpoint]

results = model.fit(X_train, Y_train, validation_split=0.2, batch_size=batch_size, epochs=epochs, callbacks=callbacks_list)
# Out:
# Epoch 1/40
# 395/395 [==============================] - ETA: 0s - loss: 0.5821 - jacard_coef: 0.2743
# Epoch 1: val_loss improved from inf to 0.66171, saving model to /content/drive/MyDrive/Sadosky_EcoDoppler/Investigación/Procesamiento/modelo_final/resultados/VGG16/unet_plaque_segmentation.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 395/395 [==============================] - 592s 1s/step - loss: 0.5821 - jacard_coef: 0.2743 - val_loss: 0.6617 - val_jacard_coef: 0.2322
# Epoch 2/40
# 395/395 [==============================] - ETA: 0s - loss: 0.4252 - jacard_coef: 0.4068
# Epoch 2: val_loss improved from 0.66171 to 0.62430, saving model to /content/drive/MyDrive/Sadosky_EcoDoppler/Investigación/Procesamiento/modelo_final/resultados/VGG16/unet_plaque_segmentation.hdf5
# 395/395 [==============================] - 505s 1s/step - loss: 0.4252 - jacard_coef: 0.4068 - val_loss: 0.6243 - val_jacard_coef: 0.2632
# Epoch 3/40
# 395/395 [==============================] - ETA: 0s - loss: 0.3643 - jacard_coef: 0.4692
# Epoch 3: val_loss improved from 0.62430 to 0.61307, saving model to /content/drive/MyDrive/Sadosky_EcoDoppler/Investigación/Procesamiento/modelo_final/resultados/VGG16/unet_plaque_segmentation.hdf5
# 395/395 [==============================] - 505s 1s/step - loss: 0.3643 - jacard_coef: 0.4692 - val_loss: 0.6131 - val_jacard_coef: 0.2699
# Epoch 4/40
# 395/395 [==============================] - ETA: 0s - loss: 0.3144 - jacard_coef: 0.5251
# Epoch 4: val_loss did not improve from 0.61307
# 395/395 [==============================] - 502s 1s/step - loss: 0.3144 - jacard_coef: 0.5251 - val_loss: 0.6496 - val_jacard_coef: 0.2460
# Epoch 5/40
# 395/395 [==============================] - ETA: 0s - loss: 0.2754 - jacard_coef: 0.5714
# Epoch 5: val_loss did not improve from 0.61307
# 395/395 [==============================] - 501s 1s/step - loss: 0.2754 - jacard_coef: 0.5714 - val_loss: 0.6421 - val_jacard_coef: 0.2559
# Epoch 6/40
# 395/395 [==============================] - ETA: 0s - loss: 0.2390 - jacard_coef: 0.6166
# Epoch 6: val_loss did not improve from 0.61307
# 395/395 [==============================] - 500s 1s/step - loss: 0.2390 - jacard_coef: 0.6166 - val_loss: 0.6459 - val_jacard_coef: 0.2491
# Epoch 7/40
# 395/395 [==============================] - ETA: 0s - loss: 0.2167 - jacard_coef: 0.6461
# Epoch 7: val_loss did not improve from 0.61307
# 395/395 [==============================] - 501s 1s/step - loss: 0.2167 - jacard_coef: 0.6461 - val_loss: 0.6398 - val_jacard_coef: 0.2541
# Epoch 8/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1964 - jacard_coef: 0.6734
# Epoch 8: val_loss did not improve from 0.61307
# 395/395 [==============================] - 500s 1s/step - loss: 0.1964 - jacard_coef: 0.6734 - val_loss: 0.6283 - val_jacard_coef: 0.2620
# Epoch 9/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1829 - jacard_coef: 0.6924
# Epoch 9: val_loss did not improve from 0.61307
# 395/395 [==============================] - 499s 1s/step - loss: 0.1829 - jacard_coef: 0.6924 - val_loss: 0.6556 - val_jacard_coef: 0.2399
# Epoch 10/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1688 - jacard_coef: 0.7127
# Epoch 10: val_loss did not improve from 0.61307
# 395/395 [==============================] - 499s 1s/step - loss: 0.1688 - jacard_coef: 0.7127 - val_loss: 0.6639 - val_jacard_coef: 0.2365
# Epoch 11/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1600 - jacard_coef: 0.7256
# Epoch 11: val_loss did not improve from 0.61307
# 395/395 [==============================] - 499s 1s/step - loss: 0.1600 - jacard_coef: 0.7256 - val_loss: 0.6421 - val_jacard_coef: 0.2549
# Epoch 12/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1555 - jacard_coef: 0.7324
# Epoch 12: val_loss did not improve from 0.61307
# 395/395 [==============================] - 498s 1s/step - loss: 0.1555 - jacard_coef: 0.7324 - val_loss: 0.6276 - val_jacard_coef: 0.2665
# Epoch 13/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1460 - jacard_coef: 0.7463
# Epoch 13: val_loss did not improve from 0.61307
# 395/395 [==============================] - 498s 1s/step - loss: 0.1460 - jacard_coef: 0.7463 - val_loss: 0.6450 - val_jacard_coef: 0.2500
# Epoch 14/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1420 - jacard_coef: 0.7525
# Epoch 14: val_loss did not improve from 0.61307
# 395/395 [==============================] - 498s 1s/step - loss: 0.1420 - jacard_coef: 0.7525 - val_loss: 0.6934 - val_jacard_coef: 0.2158
# Epoch 15/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1364 - jacard_coef: 0.7609
# Epoch 15: val_loss did not improve from 0.61307
# 395/395 [==============================] - 498s 1s/step - loss: 0.1364 - jacard_coef: 0.7609 - val_loss: 0.6815 - val_jacard_coef: 0.2251
# Epoch 16/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1330 - jacard_coef: 0.7657
# Epoch 16: val_loss did not improve from 0.61307
# 395/395 [==============================] - 498s 1s/step - loss: 0.1330 - jacard_coef: 0.7657 - val_loss: 0.6316 - val_jacard_coef: 0.2623
# Epoch 17/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1300 - jacard_coef: 0.7706
# Epoch 17: val_loss did not improve from 0.61307
# 395/395 [==============================] - 499s 1s/step - loss: 0.1300 - jacard_coef: 0.7706 - val_loss: 0.6680 - val_jacard_coef: 0.2333
# Epoch 18/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1259 - jacard_coef: 0.7772
# Epoch 18: val_loss did not improve from 0.61307
# 395/395 [==============================] - 498s 1s/step - loss: 0.1259 - jacard_coef: 0.7772 - val_loss: 0.6317 - val_jacard_coef: 0.2620
# Epoch 19/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1215 - jacard_coef: 0.7842
# Epoch 19: val_loss did not improve from 0.61307
# 395/395 [==============================] - 499s 1s/step - loss: 0.1215 - jacard_coef: 0.7842 - val_loss: 0.6318 - val_jacard_coef: 0.2614
# Epoch 20/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1189 - jacard_coef: 0.7885
# Epoch 20: val_loss did not improve from 0.61307
# 395/395 [==============================] - 499s 1s/step - loss: 0.1189 - jacard_coef: 0.7885 - val_loss: 0.6480 - val_jacard_coef: 0.2492
# Epoch 21/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1158 - jacard_coef: 0.7933
# Epoch 21: val_loss did not improve from 0.61307
# 395/395 [==============================] - 498s 1s/step - loss: 0.1158 - jacard_coef: 0.7933 - val_loss: 0.6458 - val_jacard_coef: 0.2530
# Epoch 22/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1131 - jacard_coef: 0.7974
# Epoch 22: val_loss did not improve from 0.61307
# 395/395 [==============================] - 498s 1s/step - loss: 0.1131 - jacard_coef: 0.7974 - val_loss: 0.6404 - val_jacard_coef: 0.2556
# Epoch 23/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1101 - jacard_coef: 0.8023
# Epoch 23: val_loss did not improve from 0.61307
# 395/395 [==============================] - 498s 1s/step - loss: 0.1101 - jacard_coef: 0.8023 - val_loss: 0.6569 - val_jacard_coef: 0.2412
# Epoch 24/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1118 - jacard_coef: 0.7998
# Epoch 24: val_loss did not improve from 0.61307
# 395/395 [==============================] - 498s 1s/step - loss: 0.1118 - jacard_coef: 0.7998 - val_loss: 0.6574 - val_jacard_coef: 0.2410
# Epoch 25/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1061 - jacard_coef: 0.8089
# Epoch 25: val_loss did not improve from 0.61307
# 395/395 [==============================] - 498s 1s/step - loss: 0.1061 - jacard_coef: 0.8089 - val_loss: 0.6361 - val_jacard_coef: 0.2548
# Epoch 26/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1057 - jacard_coef: 0.8095
# Epoch 26: val_loss did not improve from 0.61307
# 395/395 [==============================] - 498s 1s/step - loss: 0.1057 - jacard_coef: 0.8095 - val_loss: 0.6406 - val_jacard_coef: 0.2546
# Epoch 27/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1051 - jacard_coef: 0.8105
# Epoch 27: val_loss did not improve from 0.61307
# 395/395 [==============================] - 498s 1s/step - loss: 0.1051 - jacard_coef: 0.8105 - val_loss: 0.6204 - val_jacard_coef: 0.2694
# Epoch 28/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1043 - jacard_coef: 0.8118
# Epoch 28: val_loss did not improve from 0.61307
# 395/395 [==============================] - 498s 1s/step - loss: 0.1043 - jacard_coef: 0.8118 - val_loss: 0.6459 - val_jacard_coef: 0.2500
# Epoch 29/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1029 - jacard_coef: 0.8141
# Epoch 29: val_loss did not improve from 0.61307
# 395/395 [==============================] - 498s 1s/step - loss: 0.1029 - jacard_coef: 0.8141 - val_loss: 0.6767 - val_jacard_coef: 0.2265
# Epoch 30/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1040 - jacard_coef: 0.8123
# Epoch 30: val_loss did not improve from 0.61307
# 395/395 [==============================] - 498s 1s/step - loss: 0.1040 - jacard_coef: 0.8123 - val_loss: 0.6530 - val_jacard_coef: 0.2435
# Epoch 31/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1002 - jacard_coef: 0.8184
# Epoch 31: val_loss did not improve from 0.61307
# 395/395 [==============================] - 497s 1s/step - loss: 0.1002 - jacard_coef: 0.8184 - val_loss: 0.6409 - val_jacard_coef: 0.2553
# Epoch 32/40
# 395/395 [==============================] - ETA: 0s - loss: 0.0993 - jacard_coef: 0.8200
# Epoch 32: val_loss did not improve from 0.61307
# 395/395 [==============================] - 498s 1s/step - loss: 0.0993 - jacard_coef: 0.8200 - val_loss: 0.6393 - val_jacard_coef: 0.2562
# Epoch 33/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1004 - jacard_coef: 0.8180
# Epoch 33: val_loss did not improve from 0.61307
# 395/395 [==============================] - 497s 1s/step - loss: 0.1004 - jacard_coef: 0.8180 - val_loss: 0.6280 - val_jacard_coef: 0.2621
# Epoch 34/40
# 395/395 [==============================] - ETA: 0s - loss: 0.1017 - jacard_coef: 0.8159
# Epoch 34: val_loss did not improve from 0.61307
# 395/395 [==============================] - 497s 1s/step - loss: 0.1017 - jacard_coef: 0.8159 - val_loss: 0.6426 - val_jacard_coef: 0.2561
# Epoch 35/40
# 395/395 [==============================] - ETA: 0s - loss: 0.0995 - jacard_coef: 0.8196
# Epoch 35: val_loss did not improve from 0.61307
# 395/395 [==============================] - 497s 1s/step - loss: 0.0995 - jacard_coef: 0.8196 - val_loss: 0.6711 - val_jacard_coef: 0.2310
# Epoch 36/40
# 395/395 [==============================] - ETA: 0s - loss: 0.0989 - jacard_coef: 0.8206
# Epoch 36: val_loss did not improve from 0.61307
# 395/395 [==============================] - 497s 1s/step - loss: 0.0989 - jacard_coef: 0.8206 - val_loss: 0.6293 - val_jacard_coef: 0.2651
# Epoch 37/40
# 395/395 [==============================] - ETA: 0s - loss: 0.0974 - jacard_coef: 0.8233
# Epoch 37: val_loss did not improve from 0.61307
# 395/395 [==============================] - 498s 1s/step - loss: 0.0974 - jacard_coef: 0.8233 - val_loss: 0.6392 - val_jacard_coef: 0.2578
# Epoch 38/40
# 395/395 [==============================] - ETA: 0s - loss: 0.0989 - jacard_coef: 0.8207
# Epoch 38: val_loss did not improve from 0.61307
# 395/395 [==============================] - 498s 1s/step - loss: 0.0989 - jacard_coef: 0.8207 - val_loss: 0.6451 - val_jacard_coef: 0.2498
# Epoch 39/40
# 395/395 [==============================] - ETA: 0s - loss: 0.0988 - jacard_coef: 0.8205
# Epoch 39: val_loss did not improve from 0.61307
# 395/395 [==============================] - 498s 1s/step - loss: 0.0988 - jacard_coef: 0.8205 - val_loss: 0.6498 - val_jacard_coef: 0.2465
# Epoch 40/40
# 395/395 [==============================] - ETA: 0s - loss: 0.0981 - jacard_coef: 0.8220
# Epoch 40: val_loss did not improve from 0.61307
# 395/395 [==============================] - 497s 1s/step - loss: 0.0981 - jacard_coef: 0.8220 - val_loss: 0.6617 - val_jacard_coef: 0.2398

# %%
#from tensorflow.keras.models import load_model
#checkpoint_path = path+'unet_plaque_segmentation.hdf5'

#model = load_model(checkpoint_path,
#                     custom_objects={'dice_loss': dice_loss, 'jacard_coef': jacard_coef})

# %% [markdown]
# ## Ver desempeno de la red

# %% [markdown]
# ## visualizamos curvas de entrenamiento

# %%
## visualizamos curvas de entrenamiento

plt.figure()
plt.title("Jaccard vs epochs")
plt.plot( results.history['jacard_coef'] )
plt.plot( results.history['val_jacard_coef'] )
plt.legend(['Training Jaccard', 'Validation Jaccard'])
plt.show()

# %%
plt.figure()
plt.title("Loss vs epochs")
plt.plot( results.history['loss'] )
plt.plot( results.history['val_loss'] )
plt.legend(['Training Loss', 'Validation Loss'])
plt.show()

# %%
l=results.history['loss']
path_loss=path+'history_loss.txt'
np.savetxt(path_loss, l)

vl=results.history['val_loss']
path_v_loss=path+'history_val_loss.txt'
np.savetxt(path_v_loss, vl)

# %%
l=results.history['jacard_coef']
path_J=path+'history_Jaccard.txt'
np.savetxt(path_J, l)

vl=results.history['val_jacard_coef']
path_v_J=path+'history_val_Jaccard.txt'
np.savetxt(path_v_J, vl)

# %%
## visualizamos curvas de entrenamiento

plt.figure()
plt.title("Jaccard vs epochs")
plt.plot( results.history['jacard_coef'] )
plt.plot( results.history['val_jacard_coef'] )
plt.legend(['Training Jaccard', 'Validation Jaccard'])
plt.show()
path1=path+"Jaccard_vs_epochs.png"
plt.savefig(path1)

# %%
plt.figure()
plt.title("Loss vs epochs")
plt.plot( results.history['loss'] )
plt.plot( results.history['val_loss'] )
plt.legend(['Training Loss', 'Validation Loss'])
plt.show()
path2=path+"DICE_Loss_vs_epochs.png"
plt.savefig(path2)

# %% [markdown]
# # Test

# %%
#database_path_test = os.path.join(path_test, "clean_png_test")
database_path_test = path_test

files_test = os.listdir(database_path_test)

images_test = [item for item in files_test if 'labeled' not in item]

print(f'Total number of Test images: {len(images_test)}')
print(images_test)

test_ids = images_test
# Out:
# Total number of Test images: 48
# ['499.png', '497.png', '498.png', '504.png', '500.png', '501.png', '505.png', '503.png', '502.png', '509.png', '506.png', '510.png', '507.png', '511.png', '508.png', '513.png', '517.png', '516.png', '512.png', '515.png', '521.png', '519.png', '518.png', '523.png', '522.png', '524.png', '528.png', '527.png', '526.png', '529.png', '525.png', '531.png', '530.png', '534.png', '533.png', '532.png', '535.png', '537.png', '536.png', '540.png', '538.png', '539.png', '543.png', '541.png', '542.png', '544.png', '545.png', '520.png']

# %%
Xtest = []
Ytest = []

for image_id in test_ids:

    image_path = os.path.join(database_path_test, str(image_id))
    mask_path = os.path.join(database_path_test, image_id.replace(".png","")) + "_labeled.png"
    image = cv2.imread(image_path, 0)
    mask = cv2.imread(mask_path, 0)
    print(image.shape)
    print(mask.shape)
    Xtest.append(image[144:656, 144:656]) #eligimos el centro de tam 512x512
    Ytest.append(mask[144:656, 144:656]) #eligimos el centro de tam 512x512
# Out:
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (480, 390)
# (480, 390)
# (480, 390)
# (480, 390)
# (800, 800)
# (800, 800)

# %%
#armar nueva lista
centro_x= 400
centro_y=400

for r in range(len(test_ids)):
  h,w=Xtest[r].shape
  imagenvieja=Xtest[r]

  if h<800 or w<800:
    imagen_auxiliar=np.zeros((800,800),dtype='uint8')
    top_y=(800-h)//2
    left_x=(800-w)//2
    bottom_y = top_y + h
    right_x = left_x+w
    imagen_auxiliar[top_y:bottom_y, left_x:right_x] = imagenvieja
    imagenvieja=imagen_auxiliar


  Xtest[r]= imagenvieja[144:656, 144:656]# 512x512 centrado

# %%
#armar nueva lista
centro_x= 400
centro_y=400

for r in range(len(test_ids)):
  h,w=Ytest[r].shape
  imagenvieja=Ytest[r]

  if h<800 or w<800:
    imagen_auxiliar=np.zeros((800,800),dtype='uint8')
    top_y=(800-h)//2
    left_x=(800-w)//2
    bottom_y = top_y + h
    right_x = left_x+w
    imagen_auxiliar[top_y:bottom_y, left_x:right_x] = imagenvieja
    imagenvieja=imagen_auxiliar


  Ytest[r]= imagenvieja[144:656, 144:656]# 512x512 centrado

# %%
Y_test = np.asarray(Ytest, dtype=bool)
print('Ytrain:',Y_test.shape)

# %%
len(Xtest)

# %%
X_test = np.asarray(Xtest, dtype=np.uint8)
print('Xtest:',X_test.shape)

Y_test = np.asarray(Ytest, dtype=bool)
print('Ytest:',Y_test.shape)

r = random.randint(0, len(X_test)-1)

print(X_test[r].shape)
print(Y_test[r].shape)

# %% [markdown]
# ## Predichos para test

# %%
preds = model.predict(X_test)

# %%
print(preds.shape)

# %%
## Save the Weights
#model.save_weights("UNetW.h5")

result = preds

# aca tenemos que binarizar la prediccion del modelo
result = result > 0.5

# %%
print(result.shape)

# %%
item = random.randint(0, len(images_test)-1)
item = 16
monocroma=X_test[item]
etiqueta=Y_test[item]
red=preds[item]
print('imagen'+test_ids[item])
image_comparac(monocroma, etiqueta, red)
print('Jaccard:', jacard_coef_np(Y_test[item], preds[item][:,:,0]))
print('DICE:',dice_coef_np(Y_test[item], preds[item][:,:,0]))
# Out:
# imagen517.png
# Jaccard: 0.00033582664392512476
# DICE: 0.00033582664392512476

# %%
item = random.randint(0, len(images_test)-1)
item = 16
monocroma=X_test[item]
etiqueta=Y_test[item]
red=preds[item]
print('imagen'+test_ids[item])
image_comparac(monocroma, etiqueta, red)
print('Jaccard:', jacard_coef_np(Y_test[item], preds[item][:,:,0]))
print('DICE:',dice_coef_np(Y_test[item], preds[item][:,:,0]))

# %%
n=len(images_test)
for item in range(n):
  monocroma=X_test[item]
  etiqueta=Y_test[item]
  red=preds[item]
  print('imagen'+test_ids[item])
  image_comparac(monocroma, etiqueta, red)
  fname=path+'resultado_imagen_Test_'+test_ids[item]
  plt.savefig(fname)

# %%
n=len(images_test)
for item in range(n):
  monocroma=X_test[item]
  etiqueta=Y_test[item]
  red=preds[item]
  print('imagen'+test_ids[item])
  image_comparac(monocroma, etiqueta, red)
  fname=path+'resultado_imagen_Test_'+test_ids[item]
  plt.savefig(fname)

# %%
print('Jaccard:',jacard_coef_np(Y_test, preds[:,:,0]))
print('DICE:',dice_coef_np(Y_test, preds[:,:,0]))
print('Global')

# %%
D=0.0
J=0.0
for item in range(n):
  J=J+jacard_coef_np(Y_test[item], preds[item][:,:,0])
  D=D+dice_coef_np(Y_test[item], preds[item][:,:,0])

J=J/20
D=D/20

print('Promedio en Test')
print('Jaccard:',J)
print('DICE:',D)

# %% [markdown]
# ## Predichos para train

# %%
m=len(images_train)
pred_train = model.predict(X_train[0:m])

# %%
resul_train=pred_train >0.5

# %%
m=len(images_train)
D=0.0
J=0.0
for item in range(m):
  J=J+jacard_coef_np(Y_train[item], pred_train[item][:,:,0])
  D=D+dice_coef_np(Y_train[item], pred_train[item][:,:,0])

J=J/m
D=D/m

print('Promedio en Train')
print('Jaccard:',J)
print('DICE:',D)

# %%
item = random.randint(0, n-1)
#item = 16
monocroma=X_train[item]
etiqueta=Y_train[item]
red=pred_train[item]
print('imagen'+str(item))
image_comparac(monocroma, etiqueta, red)
print('Jaccard:',jacard_coef_np(Y_train[item], pred_train[item][:,:,0]))
print('DICE:',dice_coef_np(Y_train[item], pred_train[item][:,:,0]))

# %%
item = random.randint(0, n-1)
#item = 16
monocroma=X_train[item]
etiqueta=Y_train[item]
red=pred_train[item]
print('imagen'+str(item))
image_comparac(monocroma, etiqueta, red)
print('Jaccard:',jacard_coef_np(Y_train[item], pred_train[item][:,:,0]))
print('DICE:',dice_coef_np(Y_train[item], pred_train[item][:,:,0]))
# Out:
# imagen10
# Jaccard: 0.8830019907777776
# DICE: 0.9378610195178897
